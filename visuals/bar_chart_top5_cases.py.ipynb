# %%
import pandas as pd
import numpy as np
import matplotlib as mt
import seaborn as sns

# %%
globalcovid = pd.read_json("../data/global_covid_data.json")

# %%
globalcovid.head()
# Out:
#          updated      country  \
# 0  1746525257227  Afghanistan
# 1  1746525257219      Albania
# 2  1746525257222      Algeria
# 3  1746525257270      Andorra
# 4  1746525257248       Angola
#
#                                          countryInfo   cases  todayCases  \
# 0  {'_id': 4, 'iso2': 'AF', 'iso3': 'AFG', 'lat':...  234174           0
# 1  {'_id': 8, 'iso2': 'AL', 'iso3': 'ALB', 'lat':...  334863           0
# 2  {'_id': 12, 'iso2': 'DZ', 'iso3': 'DZA', 'lat'...  272010           0
# 3  {'_id': 20, 'iso2': 'AD', 'iso3': 'AND', 'lat'...   48015           0
# 4  {'_id': 24, 'iso2': 'AO', 'iso3': 'AGO', 'lat'...  107327           0
#
#    deaths  todayDeaths  recovered  todayRecovered  active  ...    tests  \
# 0    7996            0     211080               0   15098  ...  1390730
# 1    3605            0     330233               0    1025  ...  1941032
# 2    6881            0     183061               0   82068  ...   230960
# ...

# %%
globalcovid.isna().sum()
# Out:
# updated                   0
# country                   0
# countryInfo               0
# cases                     0
# todayCases                0
# deaths                    0
# todayDeaths               0
# recovered                 0
# todayRecovered            0
# active                    0
# critical                  0
# casesPerOneMillion        0
# deathsPerOneMillion       0
# tests                     0
# testsPerOneMillion        0
# population                0
# continent                 0
# oneCasePerPeople          0
# oneDeathPerPeople         0
# oneTestPerPeople          0
# activePerOneMillion       0
# recoveredPerOneMillion    0
# criticalPerOneMillion     0
# dtype: int64

# %%
country_wise_cases = globalcovid.pivot_table(index='country', values=['cases'], aggfunc={'cases':'sum'})
country_wise_cases.head()
# Out:
#               cases
# country
# Afghanistan  234174
# Albania      334863
# Algeria      272010
# Andorra       48015
# Angola       107327

# %%
sns.set_style(style='darkgrid')
country_wise_cases.sort_values('cases' , ascending=False).head().plot.bar(ylabel = 'Cases', xlabel = 'Country')
# Out:
# <Axes: xlabel='Country', ylabel='Cases'>
