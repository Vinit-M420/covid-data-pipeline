# %%
import pandas as pd
import numpy as np

# %%
# reading the json file created through diseases.sh 
covidindia = pd.read_json('../data/india_covid_data.json')

# %%
covidindia
# Out:
#             updated country                                 countryInfo  \
# _id   1746523456844   India                                         356
# iso2  1746523456844   India                                          IN
# iso3  1746523456844   India                                         IND
# lat   1746523456844   India                                          20
# long  1746523456844   India                                          77
# flag  1746523456844   India  https://disease.sh/assets/img/flags/in.png
#
#          cases  todayCases  deaths  todayDeaths  recovered  todayRecovered  \
# _id   45035393           0  533570            0          0               0
# iso2  45035393           0  533570            0          0               0
# iso3  45035393           0  533570            0          0               0
# lat   45035393           0  533570            0          0               0
# long  45035393           0  533570            0          0               0
# ...

# %%
covidindia = covidindia.drop(['todayCases', 'todayDeaths', 'recovered', 'todayRecovered', 'recoveredPerOneMillion' , 'critical' , 'criticalPerOneMillion'] ,axis = 1)

# %%
covidindia.reset_index()
# Out:
#   index        updated country                                 countryInfo  \
# 0   _id  1746523456844   India                                         356
# 1  iso2  1746523456844   India                                          IN
# 2  iso3  1746523456844   India                                         IND
# 3   lat  1746523456844   India                                          20
# 4  long  1746523456844   India                                          77
# 5  flag  1746523456844   India  https://disease.sh/assets/img/flags/in.png
#
#       cases  deaths    active  casesPerOneMillion  deathsPerOneMillion  \
# 0  45035393  533570  44501823               32016                  379
# 1  45035393  533570  44501823               32016                  379
# 2  45035393  533570  44501823               32016                  379
# 3  45035393  533570  44501823               32016                  379
# 4  45035393  533570  44501823               32016                  379
# ...

# %%
#Tried normalizing but it wasnt required
#pd.json_normalize(covidindia)

# %%
covidindia
# Out:
#             updated country                                 countryInfo  \
# _id   1746523456844   India                                         356
# iso2  1746523456844   India                                          IN
# iso3  1746523456844   India                                         IND
# lat   1746523456844   India                                          20
# long  1746523456844   India                                          77
# flag  1746523456844   India  https://disease.sh/assets/img/flags/in.png
#
#          cases  deaths    active  casesPerOneMillion  deathsPerOneMillion  \
# _id   45035393  533570  44501823               32016                  379
# iso2  45035393  533570  44501823               32016                  379
# iso3  45035393  533570  44501823               32016                  379
# lat   45035393  533570  44501823               32016                  379
# long  45035393  533570  44501823               32016                  379
# ...

# %%
covidindia.to_csv('../data/covidindia_df.csv', index=False)
