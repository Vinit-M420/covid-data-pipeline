# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mt

# %%
top10 = pd.read_csv('../data/top10_owid_covid_loc.csv' ,  usecols = ['location', 'total_cases'])

# %%
top10.head()
# Out:
#         location  total_cases
# 0  North America  124492666.0
# 1  United States  103436829.0
# 2          China   99373219.0
# 3  South America   68809418.0
# 4         France   38997490.0

# %%
top10.head().set_index('location').plot.bar(ylabel='cases_count'  ) #.plt.savefig('top5_total_cases.png')
# Out:
# <Axes: xlabel='location', ylabel='cases_count'>
